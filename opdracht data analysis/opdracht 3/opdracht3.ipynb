# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %% [markdown]
# # ik heb een dataset gegenereerd met chatgpt, ik wil die nu importeren en analyseren

# %%
df = pd.read_csv('student_data.csv')

# %%
df
# Out:
#       study_hours_per_week  sleep_hours_per_night  stress_level_1to10  \
# 0                35.678434               5.475363            7.879473
# 1                 7.506800               6.699307            4.356488
# 2                16.457607               5.528550            6.048779
# 3                25.438466               8.114454            3.195764
# 4                36.070570               7.860541            3.252125
# ...                    ...                    ...                 ...
# 1495             30.161313               8.177200            3.290432
# 1496             25.263533               8.588453            4.492104
# 1497             19.639511               9.289915            4.860355
# 1498              9.731351               6.362782            4.246034
# 1499             12.035626               7.031278            7.310357
#
#       caffeine_mg_per_day  exercise_minutes_per_week  \
# 0              223.352448                  63.774020
# ...

# %%
## check na first 
df.isna().sum()
# we zien dat er geen na's in zitten
# Out:
# study_hours_per_week            0
# sleep_hours_per_night           0
# stress_level_1to10              0
# caffeine_mg_per_day             0
# exercise_minutes_per_week       0
# social_media_minutes_per_day    0
# commute_minutes_per_day         0
# part_time_job_hours_per_week    0
# attendance_rate_percent         0
# late_study_ratio_0to1           0
# morningness_score_0to1          0
# year_of_study                   0
# age_years                       0
# quiz_score_avg                  0
# projects_completed              0
# gpa_1to10                       0
# study_efficiency_score          0
# manifold_1                      0
# manifold_2                      0
# label                           0
# profile                         0
# dtype: int64

# %% [markdown]
# # in deze opdrachten gebruiken wij 3 technieken
#
# - PCA
# - T-SNE
# - UMAP

# %%
# PCA 
data = df
x = data.select_dtypes(include=[np.number])  # Select only numeric columns
x_scaled = StandardScaler().fit_transform(x)
pca = PCA(n_components=2)
principal_components = pca.fit_transform(x_scaled)
pc_df = pd.DataFrame(data=principal_components, columns=['PC1', 'PC2'])
plt.figure(figsize=(8,6))
sns.scatterplot(x='PC1', y='PC2', data=pc_df)
plt.title('PCA of Student Data')
plt.show()
