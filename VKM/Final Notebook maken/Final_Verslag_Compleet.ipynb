# %% [markdown]
# Smart Study Coach

# %% [markdown]
# Verantwoording Verslag 2.2

# %% [markdown]
# Yazan Dawud & Fabiano Pungol

# %% [markdown]
# ## Data Science Life Cycle

# %% [markdown]
# ## Inhoud

# %% [markdown]
# ---
# # 1. Business Understanding

# %% [markdown]
# De eerste fase in de Data Science Life Cycle.  We definiëren hier het probleem, het gewenste resultaat van de opdrachtgever, en de basis eisen die de opdrachtgever heeft. De informatie die we krijgen van de opdrachtgever helpt om onze technische eisen in beeld te brengen en om een stappenplan te maken.

# %% [markdown]
# Ook is onze eigen inzicht als studenten zeer belangrijk bij dit aangezien wij ook mogelijk zo een recommender systeem zouden kunnen gebruiken voor onszelf. We kunnen onze eigen ervaringen en van medeleerlingen toepassen om zo een perfect mogelijk systeem te krijgen die echt werkt.

# %% [markdown]
# ## Het Probleem, en de Context van het Probleem

# %% [markdown]
# Studenten van Avans in Jaar 2 Periode 3 moeten een Vrije Keuze Module (VKM) kiezen. Het is een belangrijke keuze, omdat de VKM moet aansluiten aan de opleiding, de persoonlijke interesses, en de carrier doelen van de student.

# %% [markdown]
# Zonder hulp of lichte ondersteuning bij deze keuze is het voor studenten soms moeilijk, en niet overzichtelijk, omdat er best veel keus is. Dit kan ervoor zorgen dat een student uiteindelijk niet tevreden is met de gekozen module.

# %% [markdown]
# Avans Hogeschool wil haar studenten beter ondersteunen bij het maken van belangrijke keuzes die te maken hebben met het leertraject. Dit zou voor hun zorgen voor een hogere tevredenheid onder studenten, wat ook weer andere positieven gevolgen voor de hogeschool oplevert.

# %% [markdown]
# ## De Oplossing van Avans

# %% [markdown]
# Het maken en gebruiken van een AI-oplossing die studenten zou ondersteunen bij het maken van een keuze voor hun VKM.

# %% [markdown]
# Het product moet een werkend prototype zijn, dat de potentiële effectiviteit en efficiëntie van een AI-tool kan laten zien.

# %% [markdown]
# De oplossing moet ook schaalbaar zijn voor alle studenten aan Avans.

# %% [markdown]
# ## De Technische Oplossing

# %% [markdown]
# Het maken van een Recommender Systeem, dat op basis van informatie over de student, en informatie uit de VKM-dataset, een paar modules aanbeveelt die de goed passen bij de student zijn doelen.

# %% [markdown]
# De AI-oplossing moet

# %% [markdown]
# Het profiel van de student analyseren

# %% [markdown]
# De beste matches met de modules berekenen

# %% [markdown]
# Tenminste 3 gepersonaliseerde aanbevelingen laten zien

# %% [markdown]
# Een korte uitleg geven voor elke module aanbeveling, met een mogelijkheid tot de volledige uitleg.

# %% [markdown]
# De aanbevolen modules moeten een zo hoog mogelijke match hebben met de studentinteresse

# %% [markdown]
# De aanbevelingen moeten goed kunnen worden uitgelegd.

# %% [markdown]
# Het systeem moet in “Natural Language” werken, door de mens begrijpelijke woorden moeten als input gebruikt worden en je krijgt output terug.

# %% [markdown]
# Het model wordt vooral gebaseerd op Content-Based Filtering, met een beetje Collaborative Filtering als vergelijking met andere studenten.

# %% [markdown]
# Het model slaat data op zoals studentinteresse en datetime om te kijken hoe de interesses van studenten veranderen na verloop van tijd.

# %% [markdown]
# ## Relevante Ethische Aspecten

# %% [markdown]
# ## Identificatie van ethische aspecten

# %% [markdown]
# Privacy & Data Protection: Het is belangrijk dat gebruikers zich comfortabel voelen om informatie te delen en dat wij daar voorzichtig mee omgaan.
# AI Bias & Student Choice: We willen voorkomen dat de gebruiker later realiseert dat de AI niet open was en daardoor een verkeerde keuze heeft gemaakt.
# Transparency & Explainability: Er moet een logische verklaring en uitleg achter de aanbevelingen zitten, zeker wanneer een gebruiker de resultaten niet direct snapt.

# %% [markdown]
# ## Onderbouwing van ethische aspecten

# %% [markdown]
# Privacy & Data Protection: Het draait om het veiligstellen van data tegen misbruik of delen met derden, en het geruststellen van gebruikers dat hun gegevens niet worden gebruikt voor onbekende doeleinden.
# AI Bias & Student Choice: AI-aanbevelingen kunnen keuzes te veel forceren op basis van logica uit het verleden, terwijl een student misschien iets anders wil proberen. Het programma mag niet opdringerig zijn of slechts één richting laten zien. De AI moet goede redeneringen en voor- en nadelen benoemen, zodat de student uiteindelijk zelf kiest.
# Transparency & Explainability: De gebruiker moet de logica en het “gedachtenproces” van de aanbeveling kunnen snappen. Ook moet inzichtelijk zijn wat de impact is van de ingevulde gegevens op het resultaat.

# %% [markdown]
# ## EU AI Act:

# %% [markdown]
# De EU AI Act is een wet over productveiligheid van AI in software. Het zijn regels voor AI die ervoor zorgen dat ai veilig gebruikt word, zonder dat mensen erbij worden gemanipuleerd of gediscrimineerd.

# %% [markdown]
# Het heeft 4 klasses:

# %% [markdown]
# “Onaanvaardbaar Risico” – heel gevaarlijk of heel erg oneerlijk.

# %% [markdown]
# “Hoog Risico” – Hebben veel impact op mensenlevens, waarbij een fout door de ai iemands baan(-kansen), relaties, of gezondheid kan aanpassen.

# %% [markdown]
# “Beperkt Risico” – hebben geen echte impact op mensenlevens, maar kunnen foutieve informatie tonen. Zijn over het algemeen heel erg transparant.

# %% [markdown]
# “Minimaal Risico” – hebben geen echte mogelijk negatieve gevolgen en worden al jaren veilig gebruikt.

# %% [markdown]
# Onze ai aanbeveling tool zou in Beperkt Risico of Hoog risico vallen. Het zou momenteel Hoog Risico zijn, omdat de overheid zegt, onderwijs, sollicitaties en rechtspraak bepalen hoe iemands toekomst eruit ziet; Daarnaast aangezien wij de studenten willen nudgen om niet te snel modules uit te sluiten op basis van locatie. En ten derde, omdat onze tool gebruik maakt van persoonlijke data om een uitkomst te genereren, wat onder profilering valt.

# %% [markdown]
# We zouden een aanvraag kunnen doen om onze tool als niet-hoog risico te laten worden beschouwd.

# %% [markdown]
# Dit op basis van:

# %% [markdown]
# Een “Human-in-the-loop” wat ook in het proces hoort waar de ai gebruikt word en betekent dat uiteindelijk, een niet door ai beïnvloede persoon het nog moet goedkeuren.

# %% [markdown]
# Onze tool doet niet aan uitsluiten, het geeft enkel aanbevelingen, het schoolsysteem doet het uitsluiten maar daar heeft de ai niks mee te maken.

# %% [markdown]
# Keuzemodules zijn niet lang. Een keuzemodule duurt 10 weken en heeft dus beperkte impact op het verder leven van de student.

# %% [markdown]
# ---
# # 2. Data Acquisition & Understanding

# %% [markdown]
# We hebben een dataset gekregen met alle Vrije Keuze Modules waar studenten uit kunnen kiezen.

# %% [markdown]
# ## Uitleg Opschoonprocess VKM Dataset

# %% [markdown]
# Kleine voorbereiding en de dataset simpelweg bekijken/scannen. We hebben gekeken naar wat voor kolommen er in de dataset zaten, hoeveel rijen er zijn, en of er veel moet worden aangepast.
# Dataset bekijken en opschonen:

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

vkm_OG = pd.read_csv('Uitgebreide_VKM_dataset.csv') 

vkm_OG.head(2)
# Out:
#     id                          name  \
# 0  159  Kennismaking met Psychologie
# 1  160   Learning and working abroad
#
#                                                                                shortdescription  \
# 0  Brein, gedragsbeinvloeding, ontwikkelingspsychologie, gespreksvoering en ontwikkelingsfasen.
# 1                                      Internationaal, persoonlijke ontwikkeling, verpleegkunde
#
#                                                                                                                                              description  \
# 0  In deze module leer je hoe je gedrag van jezelf en van anderen kunt begrijpen en beinvloeden. Je maakt kennis met de basistheorie van Psychologie....
# 1  Studenten kiezen binnen de (stam) van de opleiding van Verpleegkunde steeds vaker voor een stage in het buitenland, waarbij zij de beroepsprestati...
#
# ...

# %% [markdown]
# We zagen dat de dataset 20 kolommen had en 211 rijen
# We gebruikten vkm_OG.head() om naar de dataset te kijken en vkm_OG.info om naar alle non-null waarden te kijken.

# %%
vkm_OG.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 211 entries, 0 to 210
# Data columns (total 20 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     211 non-null    int64
#  1   name                   211 non-null    object
#  2   shortdescription       191 non-null    object
#  3   description            211 non-null    object
#  4   content                211 non-null    object
#  5   studycredit            211 non-null    int64
#  6   location               211 non-null    object
#  7   contact_id             211 non-null    int64
#  8   level                  211 non-null    object
#  9   learningoutcomes       206 non-null    object
#  10  Rood                   2 non-null      float64
#  11  Groen                  2 non-null      float64
#  12  Blauw                  2 non-null      float64
#  13  Geel                   2 non-null      float64
# ...

# %%
vkm = vkm_OG.drop (columns=['Rood', 'Groen', 'Blauw', 'Geel'])

# %% [markdown]
# Vier kolommen bleken bijna helemaal leeg te zijn, Rood, Groen, Blauw, Geel, dus hebben we alle vier die kolommen verwijderd.

# %%
#Nu ga ik de content van de kolommen  description en content volledig lezen, zodat ik weet of ze duplicates van elkaar zijn en dus onnodig.
pd.set_option('display.max_colwidth', None)

# %%
#Aangezien de content kolom een duplicate is van de description kolom, ga ik deze verwijderen.
vkm = vkm.drop (columns=['content'])

# %% [markdown]
# De kolommen “description” en “content” blijken dezelfde inhoud te hebben, dus we hebben de kolom “content” verwijderd.

# %%
vkm['shortdescription'] = vkm['shortdescription'].fillna('Onbekend')
vkm['learningoutcomes'] = vkm['learningoutcomes'].fillna('Onbekend')

# %% [markdown]
# De kolommen “Shortdescription” en “learningoutcomes” hebben een paar lege rijen. Dus die hebben we allemaal ingevuld met een string: “Onbekend”.

# %%
# check if all datatypes are correct
vkm.dtypes
# Out:
# id                         int64
# name                      object
# shortdescription          object
# description               object
# studycredit                int64
# location                  object
# contact_id                 int64
# level                     object
# learningoutcomes          object
# module_tags               object
# interests_match_score    float64
# popularity_score           int64
# estimated_difficulty       int64
# available_spots            int64
# start_date                object
# dtype: object

# %%
# Change datatype of 'start_date' to datetime
vkm['start_date'] = pd.to_datetime(vkm['start_date'])
vkm.dtypes
# Out:
# id                                int64
# name                             object
# shortdescription                 object
# description                      object
# studycredit                       int64
# location                         object
# contact_id                        int64
# level                            object
# learningoutcomes                 object
# module_tags                      object
# interests_match_score           float64
# popularity_score                  int64
# estimated_difficulty              int64
# available_spots                   int64
# start_date               datetime64[ns]
# dtype: object

# %% [markdown]
# De kolom “start_date” had een verkeerd datatype, namelijk object(string), dus het datatype hebben we veranderd naar  datetime.

# %%
#nu ga ik alle tekst lowercase maken, zodat er geen duplicates ontstaan door hoofdletters.
vkm['name'] = vkm['name'].str.lower()
vkm['location'] = vkm['location'].str.lower()
vkm['module_tags'] = vkm['module_tags'].str.lower()
vkm.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Als laatste alle kolommen met datatype object(string), alle karakters lowercase gemaakt.

# %%
vkm.to_csv('Opgeschoonde_VKM_datasetv2.csv', index=False, encoding='utf-8')

# %% [markdown]
# We hebben de opgeschoonde dataset opgeslagen naar een nieuw CSV bestand. Het bevat nu 15 kolommen (ipv 20) en 211 rijen.

# %% [markdown]
# ### Uitkomst dataset:

# %%
pd.set_option('display.max_colwidth', 150)
vkm.head(2)
# Out:
#     id                          name  \
# 0  159  kennismaking met psychologie
# 1  160   learning and working abroad
#
#                                                                                shortdescription  \
# 0  Brein, gedragsbeinvloeding, ontwikkelingspsychologie, gespreksvoering en ontwikkelingsfasen.
# 1                                      Internationaal, persoonlijke ontwikkeling, verpleegkunde
#
#                                                                                                                                              description  \
# 0  In deze module leer je hoe je gedrag van jezelf en van anderen kunt begrijpen en beinvloeden. Je maakt kennis met de basistheorie van Psychologie....
# 1  Studenten kiezen binnen de (stam) van de opleiding van Verpleegkunde steeds vaker voor een stage in het buitenland, waarbij zij de beroepsprestati...
#
#    studycredit   location  contact_id  level  \
# 0           15  den bosch          58  NLQF5
# ...

# %% [markdown]
# # Data Analyse & Relevante inzichten

# %% [markdown]
# ## Exploratory Data Analysis
# We beginnen met de setup en het corrigeren van de datetime datatype

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import ast # Voor het omzetten van strings naar lijsten

vkm = pd.read_csv('Opgeschoonde_VKM_datasetv2.csv')

vkm['start_date'] = pd.to_datetime(vkm['start_date'])


def parse_tags(x):
    try:
        return ast.literal_eval(x)
    except (ValueError, SyntaxError):
        return []
        
vkm['module_tags_list'] = vkm['module_tags'].apply(parse_tags)

vkm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 211 entries, 0 to 210
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     211 non-null    int64
#  1   name                   211 non-null    object
#  2   shortdescription       211 non-null    object
#  3   description            211 non-null    object
#  4   studycredit            211 non-null    int64
#  5   location               211 non-null    object
#  6   contact_id             211 non-null    int64
#  7   level                  211 non-null    object
#  8   learningoutcomes       211 non-null    object
#  9   module_tags            211 non-null    object
#  10  interests_match_score  211 non-null    float64
#  11  popularity_score       211 non-null    int64
#  12  estimated_difficulty   211 non-null    int64
#  13  available_spots        211 non-null    int64
# ...

# %% [markdown]
# # Univariate Analyses
# We kijken naar de verdelingen van popularity_score, available_spots, en estimated_difficulty.
#
# Ook kijken we hoeveel modules er per Location, of level er zijn.

# %%
vkm[['popularity_score', 'available_spots', 'estimated_difficulty']].describe()
# Out:
#        popularity_score  available_spots  estimated_difficulty
# count        211.000000       211.000000            211.000000
# mean         254.265403        49.677725              3.156398
# std          141.703600        17.960815              1.486189
# min           10.000000        20.000000              1.000000
# 25%          135.500000        34.000000              2.000000
# 50%          265.000000        49.000000              3.000000
# 75%          374.000000        67.000000              5.000000
# max          500.000000        80.000000              5.000000

# %% [markdown]
# Hier worden al een paar dingen duidelijk.
#
# De gemmiddelde keuzemodule heeft een populariteits score van 254 op de 500.
# Er is een of meerdere modules met een populariteits score van 10 op de 500.
#
# De gemiddelde keuzemodule heeft ongeveer 50 plekken:  49.68 'available spots'.
# Er zijn keuzemodules met weinig plek, het minste is:  20 'available spots'.
# Sommige keuzemodules hebben veel plek, het meeste is: 80 'available spots'.
#
# De gemiddelde geschatte moeilijkheid is: 3.16 op de 5 'estimated difficulty'.
# Het minimale en het maximale 1 en 5.

# %%
vkm[['popularity_score', 'available_spots', 'estimated_difficulty']].hist(bins=20, figsize=(12, 6))
plt.show()

# %% [markdown]
# We zien dat er in popularity_score vooral een hele score word gegeven (de pieken).
#
# En dat er in available spots, ook erg veel verdeeldheid is, er zijn veel modules met maar 20 plekken, maar er zijn er ongeveer evenveel met 80.

# %%
vkm['location_split'] = vkm['location'].str.split(' en ')
vkm_exploded = vkm.explode('location_split')
plt.figure(figsize=(10, 6))
sns.countplot(data=vkm_exploded, x='location_split', order=vkm_exploded['location_split'].value_counts().index)
plt.show()

# %% [markdown]
# Uit deze barplot word het heel erg duidelijk dat de meeste keuzemodules in Breda of Den Bosch te volgen zijn, met ook een klein gedeelte in Tilburg.
#
# Dit betekent dat studenten die Den Bosch of Breda wegfilteren, bijna of meer dan de helft van de keuzemodules misloopt. Dat willen we voorkomen, dus we moeten de studenten nudgen oom ook naar modules in Den Bosch te kijken, of reistijd mee te wegen in het advies van de ai.
#
# Een voorbeeld van wat we kunnen doen, is ipv de mogelijkheid geven om locaties er uit te filteren, kan de gebruiker kiezen om bijv. op Breda te sorteren. Waardoor de gewenste resultaten bovenaan komen, maar de andere locaties ook er onder.

# %%
from collections import Counter


alle_tags = [tag for tags in vkm['module_tags_list'] for tag in tags]
top_10_tags = Counter(alle_tags).most_common(25)

tags, counts = zip(*top_10_tags)
plt.figure(figsize=(10, 6))
sns.barplot(x=list(counts), y=list(tags), palette='viridis')
plt.title('Top 25 Meest Voorkomende Tags')
plt.xlabel('Aantal keer voorkomend')
plt.show()
# Out:
# C:\Users\Gebruiker\AppData\Local\Temp\ipykernel_23368\2419035566.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=list(counts), y=list(tags), palette='viridis')

# %% [markdown]
# # Bivariate Analysis

# %% [markdown]
# Eerst willen we kijken of er een trend is dat studenten makkelijkere vakken leuker vinden en dus vaker kiezen.

# %%
plt.figure(figsize=(10, 6))
numeric_cols = ['studycredit', 'interests_match_score', 'popularity_score', 'available_spots', 'estimated_difficulty']
sns.heatmap(vkm[numeric_cols].corr(), annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# Het is opvallend dat er geen correlatie te vinden is tussen bijvoorbeeld 'estimated difficulty', en 'popularity_score'.
#
# De aanname dat studenten kiezen voor makkelijke studiepunten is dus niet waar in dit geval.
#
# Moeilijkheid hoeft dus niet zwaar te wegen als een negatieve factor in het aanbeveling systeem.

# %%
# popularity_score vs location excluding multiple locations
plt.figure(figsize=(10, 6))
sns.boxplot(data=vkm[vkm['location'].str.contains(' en ') == False], x='location', y='popularity_score')
plt.title('Popularity Score by Location')
# Out:
# Text(0.5, 1.0, 'Popularity Score by Location')

# %% [markdown]
# Dit laat zien dat Den Bosch de hoogste populariteit heeft, en Tilburg het laagste.

# %%
plt.figure(figsize=(10, 6))

sns.scatterplot(
    data=vkm, 
    x='available_spots', 
    y='popularity_score', 
    alpha=0.7,       # Iets doorzichtig voor als punten overlappen
    s=80,            # Vaste grootte voor alle punten
    edgecolor='white' # Wit randje om de punten voor contrast
)

plt.title('Vraag vs. Aanbod: Populariteit en Beschikbare Plaatsen', fontsize=14)
plt.xlabel('Aantal Beschikbare Plaatsen (Aanbod)', fontsize=12)
plt.ylabel('Populariteitsscore (Vraag)', fontsize=12)
plt.grid(True, linestyle='--', alpha=0.5)

plt.show()

# %% [markdown]
# Er is geen correlatie tussen capaciteit en populariteit. Wat betekent dat het onderwijs niet goed is afgestemd op de wensen van de studenten.
#
# ### Er zijn twee problemen.
#
# 1. Aangezien alle vakken links boven erg populair zijn, maar ook weinig beschikbare plaatsen hebben, zijn er veel studenten die niet de module kunnen kiezen die ze willen. Resulterend in- Ontevredenheid over Keuzemodule systeem.
#
# Ons algoritme moet dit kunnen detecteren en de studenten waarschuwen: Let Op! deze keuzemodule is erg gewild, en er is een kans dat je niet uitgekozen word. Ook moet ons product dan alternatieven die erop lijken aanbieden.
#
# 2. Rechts Onder zijn er modules die lage populariteits scores hebben, maar heel veel plek, wat er voor zorgt dat studenten moeten aansluiten bij modules die over het algemeen als slecht/minder leuk worden gezien. Resulterend in- Ontevredenheid over keuzemodule systeem.
#
# En wanneer er meer plekken zijn dan studenten, gaan er ook nog eens veel lege lokalen zijn bij de modules met een lage populariteit score.

# %%
#Explodeer de dataset: elke tag krijgt zijn eigen rij
vkm_tags_exploded = vkm.explode('module_tags_list')

# 3. Bereken de gemiddelde populariteit per tag
# We tellen ook meteen hoe vaak een tag voorkomt ('count'), 
tag_popularity = vkm_tags_exploded.groupby('module_tags_list').agg(
    avg_popularity=('popularity_score', 'mean'),
    count=('popularity_score', 'count')
).reset_index()

# 4. Filteren: We kijken alleen naar tags die minstens 3 keer voorkomen
top_tags = tag_popularity[tag_popularity['count'] >= 3].sort_values(by='avg_popularity', ascending=False).head(25)

plt.figure(figsize=(12, 6))
sns.barplot(data=top_tags, x='avg_popularity', y='module_tags_list', palette='magma')
plt.title('Top 25 Populairste Tags (Gemiddelde Score)')
plt.xlabel('Gemiddelde Populariteit')
plt.ylabel('Tag')
plt.show()
# Out:
# C:\Users\Gebruiker\AppData\Local\Temp\ipykernel_23368\2065942353.py:15: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=top_tags, x='avg_popularity', y='module_tags_list', palette='magma')

# %%
bottom_tags = tag_popularity[tag_popularity['count'] >= 3].sort_values(by='avg_popularity', ascending=True).head(25)

plt.figure(figsize=(12, 6))
sns.barplot(data=bottom_tags, x='avg_popularity', y='module_tags_list', palette='coolwarm_r')
plt.title('Top 25 Tags met de Laagste Gemiddelde Populariteit (min. 3 modules)')
plt.xlabel('Gemiddelde Populariteit')
plt.ylabel('Tag')
plt.show()
# Out:
# C:\Users\Gebruiker\AppData\Local\Temp\ipykernel_23368\1151271055.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=bottom_tags, x='avg_popularity', y='module_tags_list', palette='coolwarm_r')

# %% [markdown]
# Hieruit blijkt dat studenten een voorkeur hebben voor Technologie, Research, Smart, Zorg, onderwerpen. Terwijl techniek, analyse, kunst en filosofie juist erg laag scoren.
#
# Het is ook apart dat Technologie zo hoog scoort, maar Techniek zo laag. Misschien is het puur de woordkeuze? Studenten blijken ook hogere populariteits score te geven aan modernere termen.

# %% [markdown]
# # Content Analyse & Dimensionality Reduction
#
# We gaan hier proberen te kijken naar of de data groepen vormt, en patronen laat zien die we eerder niet konden waarnemen.

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
from sklearn.cluster import KMeans
from sklearn.feature_extraction import text
import spacy
import pandas as pd

# Zorg dat het model gedownload is (indien nog niet gedaan):
# !python -m spacy download nl_core_news_sm

# Laad het Nederlandse spacy model
nlp = spacy.load("nl_core_news_sm", disable=['parser', 'ner'])

# We gaan hier alle content in een module uit verschillende kolommen combineren tot één tekstveld
# (Zorg dat je dataframe 'vkm' hier al geladen is)
vkm['combined_content'] = vkm[['name', 'description', 'module_tags']].agg(' '.join, axis=1)

# --- STOPWOORDEN LIJSTEN ---
engelse_stopwoorden = list(text.ENGLISH_STOP_WORDS)

stopwoorden = [
    'de', 'en', 'van', 'ik', 'te', 'dat', 'die', 'in', 'een', 'hij', 'het', 'niet', 
    'zijn', 'is', 'was', 'op', 'aan', 'met', 'als', 'voor', 'had', 'er', 'maar', 
    'om', 'hem', 'dan', 'zou', 'of', 'wat', 'mijn', 'mens', 'dit', 'zo', 'door', 
    'over', 'ze', 'zich', 'bij', 'ook', 'tot', 'je', 'mij', 'uit', 'der', 'daar', 
    'haar', 'naar', 'als', 'bij', 'ons', 'u', 'deze', 'hoe', 'and', 'the', 'to', 'with', 
    'on', 'for', 'is', 'in', 'that', 'it', 'of', 'as', 'this', 'by', 'at', 'from', 'an', 
    'be', 'are', 'or', 'not', 'but', 'all', 'your', 'we', 'they', 'his', 'have', 'has', 'my', 
    'so', 'if', 'there', 'what', 'about', 'who', 'you', 'nog', 'kennis', 'studenten', 'module', 'students', 'gaan', 'waarbij', 'eerste']

extra_stopwoorden = [
    # Werkwoorden & Hulpwerkwoorden
    'worden', 'maken', 'doen', 'kunnen', 'willen', 'zullen', 'moeten', 
    'gaan', 'volgen', 'gebruiken', 'leren', 'analyseren', 'ontwikkelen',
    'toepassen', 'bieden', 'kijken', 'zien', 'staan', 'vinden',
    
    # School/Context woorden
    'module', 'minor', 'student', 'studenten', 'project', 'opdracht', 
    'werk', 'praktijk', 'onderzoek', 'hbo', 'avans', 'opleiding',
    'groep', 'individueel', 'les', 'semester', 'punten', 'ec',
    
    # Ruis / Voorzetsels / Bijwoorden
    'volgens', 'hun', 'slag', 'waarbij', 'elkaar', 'eigen', 'binnen',
    'tijdens', 'waarin', 'diverse', 'verschillende', 'centraal', 'ntb'
]

# --- FIX 1: Correct samenvoegen van lijsten voor Spacy ---
# Gebruik + in plaats van &
alle_extra_stopwoorden = extra_stopwoorden + stopwoorden

for woord in alle_extra_stopwoorden:
    nlp.vocab[woord].is_stop = True

# --- FUNCTIE ---
def clean_and_lemmatize(text):
    # Zorg voor string en lowercase
    text = str(text).lower()
    doc = nlp(text)
    
    # Lemmatize en filter stopwoorden
    # We filteren ook op lengte > 2 om 'losse letters' te voorkomen
    lemmatized = [token.lemma_ for token in doc if not token.is_stop and token.is_alpha and len(token.text) > 2]
    
    return ' '.join(lemmatized)

# --- TOEPASSEN ---
print("Bezig met lemmatization... dit kan even duren.")
vkm['processed_content'] = vkm['combined_content'].apply(clean_and_lemmatize)
print("Lemmatization voltooid.")

# Check resultaat
print(f"Origineel: {vkm['combined_content'].iloc[0][:100]}...")
print(f"Processed: {vkm['processed_content'].iloc[0][:100]}...")

# --- TF-IDF ---
# We gebruiken hier de 'processed_content' kolom, want daar zijn de stopwoorden al uit!
# Je hoeft bij TfidfVectorizer dus geen stop_words meer mee te geven (dubbel werk),
# maar het kan geen kwaad.
tfidf = TfidfVectorizer(max_features=500)
tfidf_matrix = tfidf.fit_transform(vkm['processed_content'])

print(f"TF-IDF Matrix shape: {tfidf_matrix.shape}")
# Out:
# Bezig met lemmatization... dit kan even duren.
# Lemmatization voltooid.
# Origineel: kennismaking met psychologie In deze module leer je hoe je gedrag van jezelf en van anderen kunt beg...
# Processed: kennismaking psychologie leren gedrag begrijpen beinvloed maken basistheorie psychologie bod komen o...
# TF-IDF Matrix shape: (211, 500)

# %%
pca = PCA(n_components=0.73)
pca_result = pca.fit_transform(tfidf_matrix.toarray())

print(f'Aantal componenten na PCA: {pca.n_components_}')
# Out:
# Aantal componenten na PCA: 87

# %% [markdown]
# Bij het kijken naar de PCA, zagen we dat we 187 componenten nodig hadden voor 99% variantie, wat veel te hoog is, en overfitting risceert. Daarom kiezen we nu voor 90% informatiebehoud met 132 componenten. Met 90% hebben behouden we nog bijna alle informatie, maar hebben we bijna de helft aan componenten nog.
#
# Nu staan we voor een keuze. We hebben een ai (Gemini), een berekening laten doen om het wiskundige optimale punt via de Elbow Method te ontdekken. Het resultaat is 73% informatie behoud op 87 componenten.
#
# Dit betekent dat, deze 84 componenten het belangrijkst zijn. Alle andere componenten dragen minder relevante informatie toe, en vooral informatie die maar voor 1 of 2 modules van toepassing zijn.
#
# #### We kiezen 73% met 87 componenten.
# Omdat we denken dat dit de betere keuze is die beter inzicht bied.

# %% [markdown]
# ## T-SNE en UMAP ##

# %% [markdown]
# ## t-SNE (t-Distributed Stochastic Neighbor Embedding)
# t-SNE is een niet-lineaire techniek voor dimensionaliteitsreductie, die bijzonder geschikt is voor het visualiseren van hoog-dimensionale datasets. In tegenstelling tot PCA, dat zich richt op het behouden van globale structuur en variantie, richt t-SNE zich op het behouden van lokale structuren, waardoor clusters in de data vaak beter zichtbaar worden.
#
# We passen t-SNE toe op de PCA-resultaten (om de berekening te versnellen en ruis te verminderen) en visualiseren het resultaat.

# %%
from sklearn.manifold import TSNE
X_for_tsne = pca_result

# 2. Run t-SNE
print("Calculating t-SNE... this may take a moment.")
tsne = TSNE(n_components=2, perplexity=30, init='pca', learning_rate='auto', random_state=42)
tsne_result = tsne.fit_transform(X_for_tsne)

vkm['tsne_x'] = tsne_result[:, 0]
vkm['tsne_y'] = tsne_result[:, 1]

print("t-SNE columns added to vkm!")
# Out:
# Calculating t-SNE... this may take a moment.
# t-SNE columns added to vkm!

# %%
# We kleuren de punten in op basis van 'Location' (of je kunt later Clusteren)
plt.figure(figsize=(16, 7))

# Plot 1: t-SNE
plt.subplot(1, 2, 1)
sns.scatterplot(
    data=vkm, x='tsne_x', y='tsne_y', 
    hue='location',
    palette='tab10', s=100, alpha=0.7
)
plt.title('t-SNE: Module Clustering op basis van Inhoud')
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %%
inertia = []
K_range = range(1, 15)

for k in K_range:
    km = KMeans(n_clusters=k, random_state=42, n_init=10)
    km.fit(tfidf_matrix)
    inertia.append(km.inertia_)

plt.figure(figsize=(10, 5))
plt.plot(K_range, inertia, 'bo-')
plt.xlabel('Aantal Clusters (k)')
plt.ylabel('Inertia (Totale afstand tot centrum)')
plt.title('Elbow Method: Zoek de "knik" in de lijn')
plt.grid(True)
plt.show()

# %% [markdown]
# Het is wat moeilijk te zien, maar we denken dat de elbow rond 5 of 6 zit. We nemen 6 als aantal clusters

# %%
amount_of_clusters = 6
kmeans = KMeans(n_clusters=amount_of_clusters, random_state=42)

# Laat het model NU pas rekenen
vkm['cluster'] = kmeans.fit_predict(tfidf_matrix)

print("--- DIT ZIJN DE ONDERWERPEN PER KLEUR ---")
terms = tfidf.get_feature_names_out()
order_centroids = kmeans.cluster_centers_.argsort()[:, ::-1]

cluster_labels = {} 

for i in range(amount_of_clusters):
    # Pak de top 5 woorden
    top_words = [terms[ind] for ind in order_centroids[i, :5]]
    
    # Maak de naam
    name = ", ".join(top_words)
    cluster_labels[i] = name
    
    print(f"Cluster {i}: {name}")

# Voeg de namen toe aan de dataframe
vkm['cluster_name'] = vkm['cluster'].map(cluster_labels)

# Plot 2: t-SNE met KMeans Clusters
plt.figure(figsize=(12, 8))
sns.scatterplot(
    data=vkm, 
    x='tsne_x', 
    y='tsne_y', 
    hue='cluster_name',  # Gebruik de NAMEN in de legenda
    palette='tab10',     # Goed contrast
    s=100,
    alpha=0.8
)
plt.title(f't-SNE: De {amount_of_clusters} Clusters op basis van inhoud')
# Legenda buiten de plot zetten zodat hij niet over je punten heen valt
plt.legend(bbox_to_anchor=(1.01, 1), loc=2, borderaxespad=0., title="Onderwerp")
plt.tight_layout()
plt.show()
# Out:
# --- DIT ZIJN DE ONDERWERPEN PER KLEUR ---
# Cluster 0: omgeving, bouwen, duurzaam, nieuw, business
# Cluster 1: forensisch, ontwikkeling, data, maatschappelijk, basis
# Cluster 2: design, innovatie, ontwerpen, innovation, product
# Cluster 3: software, stammodule, robot, smart, bestaan
# Cluster 4: art, research, kunst, ethisch, richten
# Cluster 5: zorg, welzijn, technologie, samenleving, mens

# %% [markdown]
# De kleuren liggen hier bijna volledig door elkaar, De enige twee duidelijke clusters zijn Rood en Groen.
#
# Maar helaas is het vooral onoverzichtelijk en door elkaar. Vooral Oranje, Blauw en Grijs is geen patroon in te vinden.

# %% [markdown]
# ## UMAP (Uniform Manifold Approximation and Projection)
# Naast PCA en t-SNE gebruiken we ook UMAP voor dimensionaliteitsreductie. UMAP is vaak sneller dan t-SNE en bewaart beter de globale structuur van de data, terwijl het ook lokale clusters goed weergeeft.
#
# We passen UMAP toe op dezelfde data als t-SNE (de PCA-resultaten of de TF-IDF matrix) en kleuren de plot opnieuw op basis van het 'level' van de modules.

# %%
import umap

X_for_umap = pca_result 

reducer = umap.UMAP(n_components=2)
umap_result = reducer.fit_transform(X_for_umap)

vkm['umap_x'] = umap_result[:, 0]
vkm['umap_y'] = umap_result[:, 1]

plt.figure(figsize=(12, 10))
sns.scatterplot(x='umap_x', y='umap_y', hue='cluster_name', data=vkm, palette='tab10', s=100, alpha=0.7)
plt.title('UMAP van VKM Modules (gekleurd op module onderwerpen)')
plt.xlabel('UMAP Dimension 1')
plt.ylabel('UMAP Dimension 2')
plt.grid(True)
plt.show()

# %% [markdown]
# We zien hier veel overlap, vooral in het midden, wat waarschijnlijk komt omdat onderwerpen zoals technologie en innovatie bij vele modules passen tegenwoordig.
#
# De Rode cluster met Zorg en Welzijn is wel duidelijk te onderscheiden van de anderen, waarschijnlijk omdat er veel woorden worden gebruikt die alleen in zulk soort opleidingen kunnnen zitten.
#
# De Rode cluster met art, research, kunst etc. is ook wel te onderscheiden, aangezien die vooral links onder van het middenpunt zit. Waarschijnlijk zijn ze niet dicht op elkaar geclusterd omdat Research erg breed is en vaak bij module beschrijvingen word gebruikt.
#
# De clustering werkt wel voor een paar specifieke onderwerpen, maar slecht voor moderne, creatieve of technologie bevattende modules, omdat dat tegenwoordig vaak tenminste een klein onderdeel is van elke module.
#
# #### Over het aanbevelingssysteem
# Een student die "zorg" leuk vind kan je veilig andere Groene modules aanraden, maar als een student een Oranje module leuk vind, wordt het riskant om andere Oranje aan te bevelen, omdat deze heel breed liggen en geen echte cluster vormen.
#
# Dus we moeten niet enkel op NLP vertrouwen, omdat dit in onze dataset niet altijd betrouwbaar genoeg is.

# %% [markdown]
# ## Grootste inzichten en conclusies:
# Op basis van de uitgevoerde Exploratory Data Analysis (EDA) en de Content Analyse kunnen we een aantal inzichten maken voor het ontwerp van het aanbevelingssysteem. De data laat zien dat filteren op 'leuke vakken' niet genoeg is; we moeten rekening houden met locatie, beschikbaarheid en de nadelen van tekstuele analyse.

# %% [markdown]
# ### 1. Studenten kiezen makkelijke modules voor 'makkelijke studiepunten' - Niet Waar

# %% [markdown]
# Het is opvallend dat er geen correlatie is gevonden tussen de geschatte moeilijkheid (estimated_difficulty) en de populariteit van een module. De aanname dat studenten kiezen voor makkelijke modules blijkt onjuist.
# Dus: We hoeven moeilijkheidsgraad niet zwaar te wegen als negatieve factor. Het is niet erg belangrijk voor de keuze van de student.

# %% [markdown]
# ### 2. Locatie en de limieten van een harde filter

# %% [markdown]
# Er is een sterke scheefgroei in het aanbod per locatie. Het overgrote deel van de modules vindt plaats in Breda en Den Bosch, waarbij modules in Den Bosch gemiddeld zelfs de hoogste populariteitsscores behalen. Tilburg blijft hierin achter.

# %% [markdown]
# Dus: Als we studenten laten filteren op locatie, missen ze soms wel meer dan de helft van het relevante aanbod. In plaats van harde filters, moeten we het systeem zo inrichten dat het sorteert op locatie, maar andere steden wel zichtbaar houdt (bijvoorbeeld met een label "Aanbevolen in Den Bosch"). We moeten studenten nudgen om ook te kijken naar de inhoud, en niet de locatie te priorisern.

# %% [markdown]
# ### 3. Mismatch in Vraag en Aanbod

# %% [markdown]
# De scatterplot tussen available_spots en popularity_score toont geen correlatie, wat wijst op een mismatch in de planning. Ongeveer 25% van de modules is populair met weinig plek, en ook ongeveer 25% is niet populair maar heeft veel plek.

# %% [markdown]
# Hoog populair / Weinig plek: Dit zorgt voor teleurstelling en uitloting. Het systeem moet hier proactief op acteren door een waarschuwing te tonen ("Let op: kans op uitloting is groot") en direct goeie, minder volle alternatieven aan te bieden.

# %% [markdown]
# Laag populair / Veel plek: Dit leidt tot inefficiëntie en studenten die 'verplicht' moeten aansluiten bij impopulaire vakken. Deze modules moeten wellicht anders gepromoot worden of inhoudelijk geanalyseerd worden op hun lage score.

# %% [markdown]
# Daarnaast laat dit zien dat er niet goed is nagedacht over de verdeling, want nu krijgen we ontevreden studenten, en lege klaslokalen bij de minder populaire met veel plek.

# %% [markdown]
# ### 4. Woordgebruik en Trends

# %% [markdown]
# Uit de module tag-analyse blijkt dat studenten erg kijken naar moderne vaktaal. Termen als Technologie, Smart en Innovation scoren hoog, terwijl traditionele termen als Techniek, Analyse en Kunst laag scoren.
#
# Dus: Bij het matchen van interesses moeten we rekening houden met synoniemen. Een student die zoekt op 'Techniek' moet wellicht gematcht worden aan 'Technologie' of 'Smart', omdat daar de populairdere inhoud zit.

# %% [markdown]
# ### 5. Beperkingen van NLP en Clustering

# %% [markdown]
# De K-Means clustering en t-SNE/UMAP visualisaties laten zien dat onze dataset alleen gedeeltelijk te clusteren is op tekst.
#
# Duidelijke clusters: De domeinen "Zorg & Welzijn" en in mindere mate "Kunst & Research" zijn goed te onderscheiden. Hier werkt content-based filtering betrouwbaar.
#
# Het geruis in het midden: Een groot deel van de modules (Business, Innovatie, Technologie) vertoont veel overlap en vormt geen duidelijke clusters. Dit komt waarschijnlijk doordat deze termen tegenwoordig in bijna elke modulebeschrijving voorkomen.

# %% [markdown]
# ### 6. Eindoordeel voor het Product

# %% [markdown]
# Een betrouwbaar aanbevelingssysteem voor deze dataset moet een hybride aanpak hanteren:
#
# Content-based filtering is veilig voor specifieke niches (zoals Zorg), maar riskant voor brede termen (zoals Innovatie).
#
# Nadenken over de capaciteit van modules is belangrijk om teleurstelling over uitloting te voorkomen.
#
# Locatie-nudging (waar we wel transparant in moeten zijn) is nodig om het volledige potentieel van het aanbod in Den Bosch en Breda te benutten.
#
# Het algoritme moet dus niet alleen kijken naar wat de student leuk vindt, maar ook de haalbaarheid (plek en locatie) zwaar meewegen in de uiteindelijke ranking.

# %% [markdown]
# ---
# # 3. Model Trainen

# %% [markdown]
# # Geavanceerd VKM Aanbevelingssysteem
#
# Welkom bij het geavanceerde aanbevelingssysteem voor VKM-modules. Dit notebook combineert een grondige data-analyse (EDA) met een slim algoritme om je te helpen de perfecte module te vinden.
#
# ## Wat doet dit systeem?
# In plaats van alleen te zoeken op trefwoorden, "begrijpt" dit systeem de inhoud van de modules. Je kunt zoeken door een beschrijving te geven van wat je wilt leren (in je eigen woorden). Daarnaast kun je filteren op:
# -   **Minimaal aantal studiepunten (EC)**
# -   **Maximale moeilijkheidsgraad**
# -   **Specifieke tags** (onderwerpen)
#
# Het systeem geeft niet alleen een lijst met modules, maar legt ook uit **waarom** een module bij je past.
#
# ## Inhoudsopgave
# 1.  **Data Inladen en Opschonen**: De basis leggen voor onze analyse.
# 2.  **Exploratieve Data Analyse (EDA)**: Inzichten in het aanbod (studiepunten, moeilijkheid, woordwolken).
# 3.  **Het Model Trainen**: De computer leren om tekst te begrijpen (TF-IDF).
# 4.  **Aanbevelingen Krijgen**: Het systeem gebruiken om modules te vinden.

# %%
from dataclasses import dataclass
from typing import List, Optional
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from wordcloud import WordCloud
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import spacy
from sklearn.feature_extraction import text

# Instellingen voor visualisaties
sns.set(style="whitegrid")
plt.rcParams['figure.figsize'] = (12, 6)

print("libraries geladen.")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[52], line 7
#       5 import matplotlib.pyplot as plt
#       6 import seaborn as sns
# ----> 7 from wordcloud import WordCloud
#       8 from sklearn.feature_extraction.text import TfidfVectorizer
#       9 from sklearn.metrics.pairwise import cosine_similarity
#
# ModuleNotFoundError: No module named 'wordcloud'

# %% [markdown]
# ## 1. Data Inladen en Opschonen
#
# We beginnen met het inladen van de dataset. We zorgen ervoor dat we alle relevante tekstkolommen samenvoegen zodat ons model zoveel mogelijk informatie heeft.

# %%
# Data inladen
file_path = 'Opgeschoonde_VKM_dataset.csv'
try:
    df = pd.read_csv(file_path)
    print(f"Dataset ingeladen met {len(df)} modules.")
except FileNotFoundError:
    print("Bestand niet gevonden. Controleer het pad.")

# Bekijk de eerste paar regels
df.head(3)
# Out:
# Dataset ingeladen met 211 modules.
#     id                          name  \
# 0  159  kennismaking met psychologie
# 1  160   learning and working abroad
# 2  161       proactieve zorgplanning
#
#                                                                                shortdescription  \
# 0  brein, gedragsbeinvloeding, ontwikkelingspsychologie, gespreksvoering en ontwikkelingsfasen.
# 1                                      internationaal, persoonlijke ontwikkeling, verpleegkunde
# 2                                                proactieve zorgplanning, cocreatie, ziekenhuis
#
# ...

# %% [markdown]
# ### Tekst Opschonen (NLP)
# Om de computer de tekst goed te laten begrijpen, moeten we "ruis" verwijderen. Dit zijn woorden die veel voorkomen maar weinig betekenis hebben (stopwoorden), zoals "de", "het", "een", "student". Ook willen we woorden terugbrengen naar hun stam (lemmatization), zodat "lopen" en "loopt" als hetzelfde worden gezien.

# %%
# Spacy model laden voor Nederlands
try:
    nlp = spacy.load("nl_core_news_sm", disable=['parser', 'ner'])
except OSError:
    print("Spacy model 'nl_core_news_sm' niet gevonden. We downloaden het nu...")
    import subprocess
    subprocess.run(["python", "-m", "spacy", "download", "nl_core_news_sm"])
    nlp = spacy.load("nl_core_news_sm", disable=['parser', 'ner'])

# Uitgebreide lijst met Nederlandse stopwoorden
stopwoorden = [
    'de', 'en', 'van', 'ik', 'te', 'dat', 'die', 'in', 'een', 'hij', 'het', 'niet', 
    'zijn', 'is', 'was', 'op', 'aan', 'met', 'als', 'voor', 'had', 'er', 'maar', 
    'om', 'hem', 'dan', 'zou', 'of', 'wat', 'mijn', 'mens', 'dit', 'zo', 'door', 
    'over', 'ze', 'zich', 'bij', 'ook', 'tot', 'je', 'mij', 'uit', 'der', 'daar', 
    'haar', 'naar', 'als', 'bij', 'ons', 'u', 'deze', 'hoe', 'and', 'the', 'to', 'with', 
    'on', 'for', 'is', 'in', 'that', 'it', 'of', 'as', 'this', 'by', 'at', 'from', 'an', 
    'be', 'are', 'or', 'not', 'but', 'all', 'your', 'we', 'they', 'his', 'have', 'has', 'my', 
    'so', 'if', 'there', 'what', 'about', 'who', 'you', 'nog', 'kennis', 'studenten', 'module', 'students', 'gaan', 'waarbij', 'eerste',
    'worden','leren', 'maken', 'doen', 'kunnen', 'willen', 'zullen', 'moeten', 
    'gaan', 'volgen', 'gebruiken', 'leren', 'analyseren', 'ontwikkelen',
    'toepassen', 'bieden', 'kijken', 'zien', 'staan', 'vinden',
    'module', 'minor', 'student', 'studenten', 'project', 'opdracht', 
    'werk', 'praktijk', 'onderzoek', 'hbo', 'avans', 'opleiding',
    'groep', 'individueel', 'les', 'semester', 'punten', 'ec',
    'volgens', 'hun', 'slag', 'waarbij', 'elkaar', 'eigen', 'binnen',
    'tijdens', 'waarin', 'diverse', 'verschillende', 'centraal', 'ntb', 'basis', 'leren'
    'ontwikkel', 'ontwikkelen', 'ontwikkeld', 'ontwikkeld'
    'maken', 'maak', 'maakt', 'maken'
    'leren', 'leren', 'leren', 'leren', 'Leren', 'lEren'
]

# Stopwoorden toevoegen aan Spacy
for woord in stopwoorden:
    nlp.vocab[woord].is_stop = True

def clean_text(text):
    if pd.isna(text):
        return ""
    text = str(text).lower()
    doc = nlp(text)
    # Lemmatize en verwijder stopwoorden en leestekens
    tokens = [token.lemma_ for token in doc if not token.is_stop and token.is_alpha and len(token.text) > 2]
    return " ".join(tokens)

# We combineren de belangrijkste kolommen tot één tekstveld
df['combined_text'] = df['name'].fillna('') + " " + df['description'].fillna('') + " " + df['learningoutcomes'].fillna('') + " " + df['module_tags'].fillna('')

print("Bezig met tekst opschonen... (dit kan even duren)")
df['processed_text'] = df['combined_text'].apply(clean_text)
print("Tekst opgeschoond!")
# Out:
# Bezig met tekst opschonen... (dit kan even duren)
# Tekst opgeschoond!

# %% [markdown]
# ## 2. Exploratieve Data Analyse (EDA)
#
# Laten we kijken wat voor modules we in huis hebben. We kijken naar de verdeling van studiepunten, moeilijkheidsgraad en de meest voorkomende woorden.

# %%
# Verdeling Studiepunten
plt.figure(figsize=(10, 5))
sns.countplot(data=df, x='studycredit', palette='viridis')
plt.title('Verdeling van Studiepunten (EC)')
plt.xlabel('Aantal Studiepunten')
plt.ylabel('Aantal Modules')
plt.show()
# Out:
# C:\Users\yazan\AppData\Local\Temp\ipykernel_20456\4145280714.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x='studycredit', palette='viridis')

# %% [markdown]
# # conclusies:
# - we zien hier dat er 120 vkms met 15 studiepunten zijn
# - we zien hier dat er 90 vkms met 30 studiepunten zijn
# - dus we hebben ongeveer 210 vkms in totaal waarvan de meeste 15 studiepunten hebben
#
# #

# %%
# Verdeling Moeilijkheidsgraad
plt.figure(figsize=(10, 5))
sns.histplot(data=df, x='estimated_difficulty', bins=5, kde=True, color='orange')
plt.title('Verdeling van Geschatte Moeilijkheidsgraad (1-5)')
plt.xlabel('Moeilijkheidsgraad')
plt.ylabel('Aantal Modules')
plt.show()

# %% [markdown]
# # conclusie
# - De moeilijkheidsgraad is niet gelijk verdeeld, er zitten juist veel modules rond niveau 1, 2 en vooral 5.
# - Niveau 3 heeft opvallend weinig modules.
# - Niveau 5 komt het meest voor, dus er zijn relatief veel moeilijke modules.
#
# De trendlijn laat een lichte stijging naar de hogere moeilijkheidsniveaus zien, wat betekent dat het aanbod gemiddeld iets naar moeilijkere modules verschuift.

# %%
# WordCloud
text_content = " ".join(df['processed_text'])
wordcloud = WordCloud(width=800, height=400, background_color='white', colormap='viridis').generate(text_content)

plt.figure(figsize=(12, 6))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('Meest voorkomende woorden in Modulebeschrijvingen')
plt.show()

# %% [markdown]
# # conclusies:
#
# - De meest dominante thema's in de modulebeschrijvingen gaan over ontwerpen, leren, samenwerken, innovatie en organisatie.
#
# - Er is veel focus op designgerichte en praktijkgerichte modules.
#
# - Woorden zoals zorg, technologie, software en creatief komen ook vaak terug, wat wijst op brede domeinen (zorg, tech, creativiteit).
#
# - Het algemene taaldomein draait vooral om leren door te doen, samenwerken en nieuwe oplossingen creëren.

# %%
plt.figure(figsize=(10, 6))
numeric_cols = ['studycredit', 'interests_match_score', 'popularity_score', 'available_spots', 'estimated_difficulty']
sns.heatmap(df[numeric_cols].corr(), annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# # conclusies
#
# - Het is opvallend dat er geen correlatie te vinden is tussen bijvoorbeeld 'estimated difficulty', en 'popularity_score'.
#
# - De aanname dat studenten kiezen voor makkelijke studiepunten is dus niet waar in dit geval.
#
# - Moeilijkheid hoeft dus niet zwaar te wegen als een negatieve factor in het aanbeveling systeem.
#
# - dus is het waarschijnlijk dat de aanbevelingssysteem beter zou kunnen werken als de moeilijkheid niet zwaar te wegen als een negatieve factor en we hier niet teveel op mioeten letten.

# %%
from collections import Counter
import ast
def parse_tags(x):
    try:
        return ast.literal_eval(x)
    except (ValueError, SyntaxError):
        return []
        
df['module_tags_list'] = df['module_tags'].apply(parse_tags)


alle_tags = [
    tag.strip().lower()
    for tags in df["module_tags_list"]
    for tag in tags
    if tag.strip().lower() not in stopwoorden
]
top_25_tags = Counter(alle_tags).most_common(25)

tags, counts = zip(*top_25_tags)
plt.figure(figsize=(10, 6))
sns.barplot(x=list(counts), y=list(tags), palette='viridis')
plt.title('Top 25 Meest Voorkomende Tags')
plt.xlabel('Aantal keer voorkomend')
plt.show()
# Out:
# C:\Users\yazan\AppData\Local\Temp\ipykernel_20456\4128307496.py:22: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=list(counts), y=list(tags), palette='viridis')

# %% [markdown]
# # conclusies:
# - stopwoorden weg gehaald
# -  zorg is meest voorkomend (18x)
# - module tags meenemen in aanbevelingssysteem zal een goede keuze worden

# %% [markdown]
# # PCA
# # Content Analyse & Dimensionality Reduction
#
# We gaan hier proberen te kijken naar of de data groepen vormt, en patronen laat zien die we eerder niet konden waarnemen.

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=0.73)
pca_result = pca.fit_transform(tfidf_matrix.toarray())

print(f'Aantal componenten na PCA: {pca.n_components_}')
# Out:
# Aantal componenten na PCA: 116

# %% [markdown]
# # t-sne

# %%
from sklearn.manifold import TSNE
X_for_tsne = pca_result

# 2. Run t-SNE
print("Calculating t-SNE... this may take a moment.")
tsne = TSNE(n_components=2, perplexity=30, init='pca', learning_rate='auto', random_state=42)
tsne_result = tsne.fit_transform(X_for_tsne)

df['tsne_x'] = tsne_result[:, 0]
df['tsne_y'] = tsne_result[:, 1]

print("t-SNE columns added to vkm!")
# Out:
# Calculating t-SNE... this may take a moment.
# t-SNE columns added to vkm!

# %%
# We kleuren de punten in op basis van 'Location' (of je kunt later Clusteren)
plt.figure(figsize=(16, 7))

# Plot 1: t-SNE
plt.subplot(1, 2, 1)
sns.scatterplot(
    data=df, x='tsne_x', y='tsne_y', 
    hue='location',
    palette='tab10', s=100, alpha=0.7
)
plt.title('t-SNE: Module Clustering op basis van Inhoud')
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %%
inertia = []
K_range = range(1, 15)

for k in K_range:
    km = KMeans(n_clusters=k, random_state=42, n_init=10)
    km.fit(tfidf_matrix)
    inertia.append(km.inertia_)

plt.figure(figsize=(10, 5))
plt.plot(K_range, inertia, 'bo-')
plt.xlabel('Aantal Clusters (k)')
plt.ylabel('Inertia (Totale afstand tot centrum)')
plt.title('Elbow Method: Zoek de "knik" in de lijn')
plt.grid(True)
plt.show()

# %% [markdown]
# Het is wat moeilijk te zien, maar we denken dat de elbow rond 5 of 6 zit. We nemen 6 als aantal clusters

# %%
from sklearn.cluster import KMeans
amount_of_clusters = 6
kmeans = KMeans(n_clusters=amount_of_clusters, random_state=42)

# Laat het model NU pas rekenen
df['cluster'] = kmeans.fit_predict(tfidf_matrix)

print("--- DIT ZIJN DE ONDERWERPEN PER KLEUR ---")
terms = tfidf.get_feature_names_out()
order_centroids = kmeans.cluster_centers_.argsort()[:, ::-1]

cluster_labels = {} 

for i in range(amount_of_clusters):
    # Pak de top 5 woorden
    top_words = [terms[ind] for ind in order_centroids[i, :5]]
    
    # Maak de naam
    name = ", ".join(top_words)
    cluster_labels[i] = name
    
    print(f"Cluster {i}: {name}")

# Voeg de namen toe aan de dataframe
df['cluster_name'] = df['cluster'].map(cluster_labels)

# Plot 2: t-SNE met KMeans Clusters
plt.figure(figsize=(12, 8))
sns.scatterplot(
    data=df, 
    x='tsne_x', 
    y='tsne_y', 
    hue='cluster_name',  # Gebruik de NAMEN in de legenda
    palette='tab10',     # Goed contrast
    s=100,
    alpha=0.8
)
plt.title(f't-SNE: De {amount_of_clusters} Clusters op basis van inhoud')
# Legenda buiten de plot zetten zodat hij niet over je punten heen valt
plt.legend(bbox_to_anchor=(1.01, 1), loc=2, borderaxespad=0., title="Onderwerp")
plt.tight_layout()
plt.show()
# Out:
# --- DIT ZIJN DE ONDERWERPEN PER KLEUR ---
# Cluster 0: bouwen, omgeving, duurzaam, interdisciplinair, maatschappelijk
# Cluster 1: water, research, multidisciplinary, will, transition
# Cluster 2: zorg, design, welzijn, product, ontwerpen
# Cluster 3: data, chemie, bedrijf, datum, leren
# Cluster 4: innovatie, art, formuleren, organisatie, sociaal
# Cluster 5: samenleving, welzijn, zorg, leefstijl, jeugd

# %% [markdown]
# De kleuren liggen hier bijna volledig door elkaar, De enige twee duidelijke clusters zijn Rood en Groen.
#
# Maar helaas is het vooral onoverzichtelijk en door elkaar. Vooral Oranje, Blauw en Grijs is geen patroon in te vinden.

# %% [markdown]
# ## UMAP (Uniform Manifold Approximation and Projection)
# Naast PCA en t-SNE gebruiken we ook UMAP voor dimensionaliteitsreductie. UMAP is vaak sneller dan t-SNE en bewaart beter de globale structuur van de data, terwijl het ook lokale clusters goed weergeeft.
#
# We passen UMAP toe op dezelfde data als t-SNE (de PCA-resultaten of de TF-IDF matrix) en kleuren de plot opnieuw op basis van het 'level' van de modules.

# %%
import umap

X_for_umap = pca_result 

reducer = umap.UMAP(n_components=2)
umap_result = reducer.fit_transform(X_for_umap)

df['umap_x'] = umap_result[:, 0]
df['umap_y'] = umap_result[:, 1]

plt.figure(figsize=(12, 10))
sns.scatterplot(x='umap_x', y='umap_y', hue='cluster_name', data=df, palette='tab10', s=100, alpha=0.7)
plt.title('UMAP van VKM Modules (gekleurd op module onderwerpen)')
plt.xlabel('UMAP Dimension 1')
plt.ylabel('UMAP Dimension 2')
plt.grid(True)
plt.show()

# %% [markdown]
# We zien hier veel overlap, vooral in het midden, wat waarschijnlijk komt omdat onderwerpen zoals technologie en innovatie bij vele modules passen tegenwoordig.
#
# De Rode cluster met Zorg en Welzijn is wel duidelijk te onderscheiden van de anderen, waarschijnlijk omdat er veel woorden worden gebruikt die alleen in zulk soort opleidingen kunnnen zitten.
#
# De Rode cluster met art, research, kunst etc. is ook wel te onderscheiden, aangezien die vooral links onder van het middenpunt zit. Waarschijnlijk zijn ze niet dicht op elkaar geclusterd omdat Research erg breed is en vaak bij module beschrijvingen word gebruikt.
#
# De clustering werkt wel voor een paar specifieke onderwerpen, maar slecht voor moderne, creatieve of technologie bevattende modules, omdat dat tegenwoordig vaak tenminste een klein onderdeel is van elke module.
#
# #### Over het aanbevelingssysteem
# Een student die "zorg" leuk vind kan je veilig andere Groene modules aanraden, maar als een student een Oranje module leuk vind, wordt het riskant om andere Oranje aan te bevelen, omdat deze heel breed liggen en geen echte cluster vormen.
#
# Dus we moeten niet enkel op NLP vertrouwen, omdat dit in onze dataset niet altijd betrouwbaar genoeg is.

# %% [markdown]
# # Het Model Trainen (TF-IDF)
#
# We gebruiken TF-IDF (Term Frequency-Inverse Document Frequency) om de tekst om te zetten in getallen. Dit algoritme geeft gewicht aan woorden die uniek zijn voor een module, en minder gewicht aan woorden die overal voorkomen.

# %%
# TF-IDF Vectorizer initialiseren
tfidf = TfidfVectorizer()

# De matrix maken
tfidf_matrix = tfidf.fit_transform(df['processed_text'])

print(f"TF-IDF Matrix vorm: {tfidf_matrix.shape} (Modules, Unieke Woorden)")
# Out:
# TF-IDF Matrix vorm: (211, 3419) (Modules, Unieke Woorden)

# %% [markdown]
# ## Aanbevelingen Krijgen
#
# Hier bouwen we de functie die jouw input vertaalt naar concrete aanbevelingen.
#
# **Hoe werkt het?**
# 1.  We filteren eerst op je harde eisen (studiepunten, moeilijkheid).
# 2.  We berekenen hoe goed jouw zoektekst past bij de overgebleven modules (Cosine Similarity).
# 3.  We geven de beste matches terug met een uitleg.

# %%
@dataclass
class CandidateProfile:
    interests_text: str
    preferred_location: Optional[str] = None
    min_studycredits: Optional[float] = None
    max_difficulty: Optional[float] = None
    moduletags_include: Optional[List[str]] = None

# %%
def geef_aanbeveling(profile: CandidateProfile, weights: dict = None, k=5):
    # Standaard gewichten als deze niet zijn opgegeven
    if weights is None:
        weights = {
            'text_similarity': 1.0,  # Basis gewicht voor inhoudelijke match
            'location': 0.5,         # Bonus voor juiste locatie (belangrijk!)
            'tags': 0.3,             # Bonus per matchende tag
            'difficulty': 0.2        # Strafpunten per punt moeilijkheid boven limiet
        }
    
    # 1. Filteren (Harde eisen)
    # We houden studiepunten als harde eis omdat dit vaak administratief noodzakelijk is.
    filtered_df = df.copy()
    if profile.min_studycredits is not None:
        filtered_df = filtered_df[filtered_df['studycredit'] >= profile.min_studycredits]
        
    if len(filtered_df) == 0:
        return "Geen modules gevonden die aan de harde eis voor studiepunten voldoen."

    # 2. Bereken Scores
    
    # A. Tekstuele Match (TF-IDF)
    clean_query = clean_text(profile.interests_text)
    query_vec = tfidf.transform([clean_query])
    subset_indices = filtered_df.index
    subset_tfidf = tfidf_matrix[subset_indices]
    similarities = cosine_similarity(query_vec, subset_tfidf).flatten()
    
    # B. Bereken totale score per module
    results = []
    
    for idx, (original_idx, row) in enumerate(filtered_df.iterrows()):
        # Basis score: Tekst similarity
        text_score = similarities[idx]
        final_score = text_score * weights.get('text_similarity', 1.0)
        
        reasons = []
        if text_score > 0.15:
            reasons.append(f"Inhoudelijk goede match ({text_score * 100:.2f}%).")
        
        # Locatie Bonus
        loc_bonus = 0
        if profile.preferred_location and pd.notna(row['location']):
            if profile.preferred_location.lower() in str(row['location']).lower():
                loc_bonus = weights.get('location', 0.5)
                reasons.append(f"Locatie match ({row['location']}).")
            else:
                # Geen straf, maar wel vermelden in redenatie als het anders is
                # reasons.append(f"Andere locatie ({row['location']}).")
                pass
        final_score += loc_bonus
        
        # Tag Bonus
        tag_bonus = 0
        if profile.moduletags_include and pd.notna(row['module_tags']):
            # Tags zijn string representatie van lijst
            row_tags = str(row['module_tags']).lower()
            matching_tags = [tag for tag in profile.moduletags_include if tag.lower() in row_tags]
            if matching_tags:
                # Bonus per tag
                tag_bonus = len(matching_tags) * weights.get('tags', 0.3)
                reasons.append(f"Tags matchen: {', '.join(matching_tags)}.")
        final_score += tag_bonus
        
        # Moeilijkheid Penalty
        diff_penalty = 0
        if profile.max_difficulty is not None and pd.notna(row['estimated_difficulty']):
            diff = float(row['estimated_difficulty'])
            if diff > profile.max_difficulty:
                diff_diff = diff - profile.max_difficulty
                diff_penalty = diff_diff * weights.get('difficulty', 0.2)
                reasons.append(f"Let op: Iets moeilijker ({diff}) dan gewenst ({profile.max_difficulty}).")
        final_score -= diff_penalty
        
        # Opslaan
        results.append({
            'Module': row['name'],
            'Locatie': row['location'],
            'Score': final_score,
            'EC': row['studycredit'],
            'Moeilijkheid': row['estimated_difficulty'],
            'Redenering': " ".join(reasons) if reasons else "Match op basis van algemene criteria."
        })
    
    # 3. Sorteren en Top K
    results_df = pd.DataFrame(results)
    if not results_df.empty:
        results_df = results_df.sort_values(by='Score', ascending=False).head(k)
    
    return results_df

# %% [markdown]
# ## Interactie Voorbeeld
# Hieronder kun je het systeem testen. Pas de variabelen aan om te zien wat er gebeurt.

# %%
#optioneel: custom weights door studenten laten gevne (???!)
mijn_gewichten = {
    'text_similarity': 1.0,  # Hoe belangrijk is de tekstmatch?
    'location': 0.8,         # Hoge bonus voor locatie (zoals gevraagd)
    'tags': 0.3,             # Bonus per tag
    'difficulty': 0.1        # Lage straf voor moeilijkheid
}

profiel = CandidateProfile(
    interests_text="Ik wil leren over data science, python en machine learning.",
    preferred_location="Breda", 
    min_studycredits=15,
    max_difficulty=5,
    moduletags_include=['data', 'python', 'machine learning', 'data science', 'AI']
)
pd.set_option("display.max_colwidth", None)


print("Zoeken naar aanbevelingen voor profiel:")
print(profiel)
print("-"*50)

aanbevelingen = geef_aanbeveling(profiel)
aanbevelingen
# Out:
# Zoeken naar aanbevelingen voor profiel:
# CandidateProfile(interests_text='Ik wil leren over data science, python en machine learning.', preferred_location='Breda', min_studycredits=15, max_difficulty=5, moduletags_include=['data', 'python', 'machine learning', 'data science', 'AI'])
# --------------------------------------------------
#                                         Module             Locatie     Score  \
# 130        datagedreven besluitvorming met ai                breda  1.701198
# 171  molecular modeling & data-driven analysis               breda  1.564454
# 167                         forensische chemie  breda en den bosch  0.939082
# 146        smart industry & internet of things               breda  0.902066
# 173                   sustainable supply chain               breda  0.837501
#
#      EC  Moeilijkheid  \
# 130  15             4
# 171  30             1
# 167  15             5
# 146  30             3
# 173  15             4
#
# ...

# %%
# exporteren naar pkl

# %% [markdown]
# ---
# # ⬆️ EINDE BIJLAGE: Geavanceerd_VKM_Aanbevelingssysteem.ipynb
# ---

# %% [markdown]
# ## Model trainen en tekst naar vectoren

# %% [markdown]
# Voor het recommender systeem gebruiken we een content based model op basis van TF-IDF en cosinus-similarity. De belangrijkste stappen:

# %% [markdown]
# Tekstvelden combineren tot VKM_text

# %% [markdown]
# We hebben meerdere tekstkolommen samengevoegd, zoals shortdescription, description, learningoutcomes en module_tags, in één nieuwe kolom VKM_text. Lege waarden zijn vervangen door een lege string en alle tekst is opgeschoond naar lowercase zonder dubbele spaties. Hierdoor heeft elke VKM één rijke tekstbeschrijving.

# %% [markdown]
# TF-IDF vectorizer trainen

# %% [markdown]
# We gebruiken TfidfVectorizer uit scikit-learn.

# %% [markdown]
# Nederlandse stopwoorden komen uit NLTK (stopwords.words("dutch")), zodat woorden zoals "de", "het" en "een" geen gewicht krijgen.

# %% [markdown]
# Instellingen: max_features=8000 en ngram_range= (1, 2) zodat zowel losse woorden als woordcombinaties (bi-grams) worden meegenomen.

# %% [markdown]
# De vectorizer wordt met fit_transform getraind op de kolom VKM_text. Dit levert een grote sparse matrix X op waarin elke rij een module is en elke kolom een TF-IDF gewicht van een term.

# %% [markdown]
# Studentprofiel naar vector

# %% [markdown]
# We definiëren een CandidateProfile class met velden zoals interests_text, preferred_location, min_studycredits, max_difficulty en optionele moduletags_include.

# %% [markdown]
# De vrije tekst in interests_text gaat via dezelfde TF-IDF vectorizer naar een vector met tfidf.transform([profile.interests_text]).

# %% [markdown]
# Omdat zowel modules als profiel in dezelfde vectorruimte zitten, kunnen we ze rechtstreeks vergelijken.

# %% [markdown]
# Content similarity en constraint score

# %% [markdown]
# Met cosine_similarity(profile_vector, X) berekenen we voor elke module een content score tussen 0 en 1.

# %% [markdown]
# Daarnaast berekenen we per module een constraint score met de functie constraint_score, die kijkt naar:

# %% [markdown]
# Locatie (zwaarste gewicht),

# %% [markdown]
# Aanwezigheid van gevraagde tags,

# %% [markdown]
# Maximale moeilijkheid (estimated_difficulty),

# %% [markdown]
# Minimum studiepunten (studycredit).

# %% [markdown]
# Binnen constraint_score gebruiken we gewichten, bijvoorbeeld 0,4 voor locatie, 0,3 voor tags, 0,2 voor moeilijkheid en 0,1 voor studiepunten. Alles wordt gecombineerd tot één score tussen 0 en 1. dit is nog simpel aanpasbaar voor het geval we later een ander gewicht willen meegeven.

# %% [markdown]
# Eindscore en populariteit

# %% [markdown]
# Er is een helper first_existing_col om juiste kolomnamen te vinden en een functie om numerieke waarden uit tekstkolommen te halen.

# %% [markdown]
# De functie recommend(profile, k, alpha, beta, gamma) combineert drie componenten:

# %% [markdown]
# content similarity (alpha),

# %% [markdown]
# constraint score (beta),

# %% [markdown]
# Genormaliseerde popularity_score op basis van min-max scaling (gamma).

# %% [markdown]
# Standaard gebruiken we bijvoorbeeld alpha=0.7, beta=0.2, gamma=0.1. De eindscore per module is: final_score = alpha * content_sim + beta * constraint_score + gamma * popularity_score.

# %% [markdown]
# De top k modules met hoogste final_score worden geretourneerd als aanbevelingen.

# %% [markdown]
# Model bewaren

# %% [markdown]
# Voor later gebruik slaan we de getrainde TF-IDF vectorizer, de opgeschoonde dataframe df en de matrix X op met joblib.dump in models/vkm_recommender.pkl.

# %% [markdown]
# ## Evaluatie: werkt het model en hoe maken we het beter?

# %% [markdown]
# Hoe testen we of het werkt?

# %% [markdown]
# We maken een demo studentprofiel (bijvoorbeeld interesses in "data analytics machine learning python",
# locatie Breda,
# min. 15 studiepunten,
# max. moeilijkheid 4,
# tags ["data", "analytics"])

# %% [markdown]
# En laten het systeem aanbevelingen doen.

# %% [markdown]
# De top 5 resultaten bekijken we inhoudelijk:

# %% [markdown]
# Sluiten de onderwerpen aan bij de opgegeven interesses,

# %% [markdown]
# Kloppen locatie, studiepunten en moeilijkheid,

# %% [markdown]
# Zijn de modules niet allemaal precies hetzelfde type.

# %% [markdown]
# Met diversity_score(indices) berekenen we de gemiddelde onderlinge overeenkomst van de top-k, op basis van de TF-IDF vectoren. Een hoge diversiteitsscore (dicht bij 1) betekent dat de lijst gevarieerd is.

# %% [markdown]
# Met explain_overlap(profile_text, module_text) halen we de belangrijkste overlappende sleutelwoorden uit profiel en moduletekst. Deze worden per aanbeveling uitgeprint als uitleg waarom de match tot stand is gekomen.

# %% [markdown]
# ## Wat kunnen we aanpassen om het beter te laten werken?

# %% [markdown]
# TF-IDF instellingen verder fine tunen

# %% [markdown]
# max_features verlagen of verhogen om minder of meer woorden te gebruiken.

# %% [markdown]
# ngram_range aanpassen, bijvoorbeeld alleen unigrams of juist ook tri-grams als dat zinvol is.

# %% [markdown]
# Stopwoordenlijst uitbreiden met veel voorkomende Avans-specifieke woorden die weinig zeggen over inhoud.

# %% [markdown]
# Weging van scores aanpassen

# %% [markdown]
# alpha, beta, gamma finetunen als blijkt dat het model te veel op tekst lijkt te focussen en te weinig op praktische eisen, of andersom.

# %% [markdown]
# Binnen constraint_score de gewichten voor locatie, tags, moeilijkheid en studiepunten aanpassen als bijvoorbeeld locatie in de praktijk nog belangrijker blijkt te zijn.

# %% [markdown]
# Constraints en filtering verder aanscherpen

# %% [markdown]
# Alleen modules aanbevelen met voldoende available_spots en een start_date in de toekomst.

# %% [markdown]
# Extra harde filters toevoegen per profiel, bijvoorbeeld alleen modules op een bepaald niveau of alleen Nederlandstalige modules.

# %% [markdown]
# Kwalitatieve feedback gebruiken
# Tijdens gebruik studenten laten aangeven of een aanbeveling nuttig was en dit later gebruiken om de wegingen aan te passen of extra regels toe te voegen.
